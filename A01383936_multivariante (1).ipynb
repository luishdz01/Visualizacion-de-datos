# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
import seaborn as sns; sns.set()
import pandas as pd
pd.set_option('max_columns', None)
import re
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('datasets/antropometria-dataset.csv')
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla emb temb  cintura  cadera  sistol  diastol  \
# 0          8  73.70     2  146.40   4         98.70   106.0   63.25    53.25
# 1         11  35.65     2  145.10             64.00    75.0   70.00    50.00
# 2          8  54.80     1  162.00   4         67.60    94.3   70.50    41.00
# 3          8  33.40     2  146.50             60.60    72.2   71.00    64.00
# 4          3  97.95     2  161.00   4        113.00   127.0   72.00    53.50
# ...      ...    ...   ...     ...  ..  ...      ...     ...     ...      ...
# 18635     11  75.80     1  141.15             93.00   113.0  221.00    95.50
# 18636      0  69.40     1  144.80            103.05   113.7  222.25    78.00
# 18637      7  46.75     2  149.20             71.35    86.0  230.00    66.00
# 18638      7  59.05     2  142.50             99.95    94.8  235.00   100.00
# 18639      8  80.00     2  150.65            108.15   120.0  240.00   150.00
#
#       hpresion tbrazo htension  PrimaryLast code_upm  est_dis  est_urb  \
# 0        16:30      2    16:35            1    R2101        5        3
# 1        15:25      3    15:25            1    M1041        1        1
# 2         9:40      1     9:40            1    M0108        5        3
# 3         7:40      3     7:45            1    M0931        4        3
# 4         6:00      2     6:00            1    M2123        5        3
# ...        ...    ...      ...          ...      ...      ...      ...
# 18635    18:00      1    18:05            1    R3002        5        3
# 18636    18:40      1    18:40            1    M0408        5        3
# 18637     8:00      3    23:00            1    M3024        2        1
# 18638     6:02      3     6:02            1    M2512        3        2
# 18639    13:50      3    13:00            1    M0143        2        1
#
#        est_marg       pondef  est_var
# 0             1  3470.002176      215
# 1             1   417.946672      101
# 2             1   472.980811       15
# 3             2  1832.581391       94
# 4             1  7622.066564      215
# ...         ...          ...      ...
# 18635         1  7615.607749      305
# 18636         1   195.314670       45
# 18637         2  1758.912979      302
# 18638         1  2354.581350      253
# 18639         2   591.847039       12
#
# [18640 rows x 26 columns]

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.hist(df['sistol'],bins= 20)
plt.title('Sistol')

plt.subplot(2,2,2)
plt.hist(df['diastol'],bins=20)
plt.title('Diastol')

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.hist(df['peso'], bins=20)
plt.title('Peso:')

plt.subplot(2,2,2)
plt.hist(df['cintura'], bins=20)
plt.title('Cintura:')

plt.show()

# %%
sns.lmplot(x= 'cintura',
          y = 'peso',
           hue='sexo',
          data = df)

plt.show()
