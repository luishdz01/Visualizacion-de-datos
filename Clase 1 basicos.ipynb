# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
print('hola')
# Out:
# hola

# %%
nombre= 'Luis'
print(nombre)
# Out:
# Luis

# %%
import numpy as np
n=50
numeros_random= np.random.rand(n)
print(numeros_random)
# Out:
# [0.59966368 0.02068695 0.28946635 0.43611792 0.19419678 0.29800132
#  0.57056051 0.08045211 0.02356195 0.45829373 0.6709185  0.2013705
#  0.11878703 0.08542249 0.66792796 0.5937255  0.30973723 0.99147594
#  0.53113881 0.42916261 0.70008441 0.07899881 0.17850728 0.89794764
#  0.6378138  0.95022451 0.28988185 0.49659669 0.92225436 0.95862397
#  0.84938357 0.22877678 0.12103498 0.21227187 0.35745632 0.3343802
#  0.89495039 0.86268527 0.3437467  0.18850748 0.43630946 0.7342003
#  0.8949792  0.39584724 0.82407459 0.16856168 0.71426661 0.18420243
#  0.54893595 0.71083345]

# %%
import math
type (4)
# Out:
# int

# %%
type(2.5)
# Out:
# float

# %%
type(None)
# Out:
# NoneType

# %%
type(True)
# Out:
# bool

# %%
an_array=[1, 2, 3, 4, 10]
an_array
# Out:
# [1, 2, 3, 4, 10]

# %%
print(an_array)
# Out:
# [1, 2, 3, 4, 10]

# %%
suma=sum(an_array)
suma
# Out:
# 20

# %%
mean_an_array= suma/len(an_array)
mean_an_array
# Out:
# 4.0

# %%
otro_array= [2, math.pi, 3/5, 'a_str']
otro_array
# Out:
# [2, 3.141592653589793, 0.6, 'a_str']

# %%
x=6
y=8

if x<y:
    print('{} es menor que {}' .format(x,y))
else:
    print('{} es menor que {}' .format(y,x))
# Out:
# 6 es menor que 8)

# %%
list=[True, 6<5, 1==3, None is None]
list
# Out:
# [True, False, False, True]

# %%
for i in list:
    print('{} \t {}' .format(i, type(i)))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %%
for i in list:
    print(i, '\t', type(i))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %%
x=None
type(x)
# Out:
# NoneType

# %%
none_list=[None]*5
none_list
# Out:
# [None, None, None, None, None]

# %%
len(none_list)
# Out:
# 5

# %%
una_lista=['pos0','1', '2', '3', '4', '5']
una_lista
# Out:
# ['pos0', '1', '2', '3', '4', '5']

# %%
una_lista[4]
# Out:
# '4'

# %%
una_lista[1:4]
# Out:
# ['1', '2', '3']

# %%
np.mean(num_array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-4d8d6664a819> in <module>
# ----> 1 np.mean(num_array)
#
# NameError: name 'num_array' is not defined

# %%
np.dot(3,4)
# Out:
# 12

# %%
np.dot([2j, 3j], [2j, 3j])
# Out:
# (-13+0j)

# %%
import pandas as pd

data_set= 'datasets/Cartwheeldata.csv'
df= pd.read_csv(data_set)

# %%
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
index_list=list(df.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-3279d6ef6e6f> in <module>
# ----> 1 index_list=list(df.columns)
#
# TypeError: 'list' object is not callable

# %%
for i in df.columns:
    print(i)
# Out:
# ID
# Age
# Gender
# GenderGroup
# Glasses
# GlassesGroup
# Height
# Wingspan
# CWDistance
# Complete
# CompleteGroup
# Score

# %%
x=df['Height']
print(x)
print(type(x))
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
y=df[['Height']]
print(y)
print(type(y))
# Out:
#     Height
# 0    62.00
# 1    62.00
# 2    66.00
# 3    64.00
# 4    73.00
# 5    75.00
# 6    75.00
# 7    65.00
# 8    74.00
# 9    63.00
# 10   69.50
# 11   62.75
# 12   65.00
# 13   61.50
# 14   73.00
# 15   71.00
# 16   61.50
# 17   66.00
# 18   70.00
# 19   68.00
# 20   69.00
# 21   71.00
# 22   70.00
# 23   69.00
# 24   65.00
# <class 'pandas.core.frame.DataFrame'>

# %%
df[['Height', 'Gender']]
# Out:
#     Height Gender
# 0    62.00      F
# 1    62.00      F
# 2    66.00      F
# 3    64.00      F
# 4    73.00      M
# 5    75.00      M
# 6    75.00      M
# 7    65.00      F
# 8    74.00      M
# 9    63.00      F
# 10   69.50      M
# 11   62.75      F
# 12   65.00      F
# 13   61.50      F
# 14   73.00      M
# 15   71.00      M
# 16   61.50      F
# 17   66.00      M
# 18   70.00      M
# 19   68.00      F
# 20   69.00      M
# 21   71.00      M
# 22   70.00      M
# 23   69.00      M
# 24   65.00      F

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.loc[1:4]
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.loc[:3, 'GenderGroup':'Complete']
# Out:
#    GenderGroup Glasses  GlassesGroup  Height  Wingspan  CWDistance Complete
# 0            1       Y             1    62.0      61.0          79        Y
# 1            1       Y             1    62.0      60.0          70        Y
# 2            1       Y             1    66.0      64.0          85        Y
# 3            1       N             0    64.0      63.0          87        Y

# %%
df.iloc[:3, 1:4]
# Out:
#    Age Gender  GenderGroup
# 0   56      F            1
# 1   26      F            1
# 2   33      F            1

# %%
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.Height.unique()
# Out:
# array([62.  , 66.  , 64.  , 73.  , 75.  , 65.  , 74.  , 63.  , 69.5 ,
#        62.75, 61.5 , 71.  , 70.  , 68.  , 69.  ])

# %%
df.groupby(['Height', 'GenderGroup']).size()
# Out:
# Height  GenderGroup
# 61.50   1              2
# 62.00   1              2
# 62.75   1              1
# 63.00   1              1
# 64.00   1              1
# 65.00   1              3
# 66.00   1              1
#         2              1
# 68.00   1              1
# 69.00   2              2
# 69.50   2              1
# 70.00   2              2
# 71.00   2              2
# 73.00   2              2
# 74.00   2              1
# 75.00   2              2
# dtype: int64
